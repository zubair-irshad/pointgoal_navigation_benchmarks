# %%
import gzip
import json
test_data_path = '/home/mirshad7/habitat-api/data/datasets/pointnav/gibson/v1/all/training_batch_0.json.gz'
    
with gzip.open(test_data_path, "rt") as f:
    test = json.loads(f.read())
    
print(len(test['episodes']))

print(test['episodes'][1]['info']['geodesic_distance'])

gd=[]
for i in range(len(test['episodes'])):
    gd.append(test['episodes'][i]['info']['geodesic_distance'])
    
print(sum(i > 14 for i in gd))

print (min(gd))
print (max(gd))
# Out:
# 720
# 5.695267677307129
# 27
# 1.1071720123291016
# 20.38917350769043

# %% [markdown]
# # Testing dataloader for RNN

# %%
from Project import Project
project = Project() 
import torch
from dataset import Dataset_RNN
import torch.utils.data as data
import torchvision.transforms as transforms
from expert import Expert
from torch.nn.utils.rnn import pad_sequence

# Detect devices
use_cuda = torch.cuda.is_available()                   # check if GPU exists
device = torch.device("cuda" if use_cuda else "cpu")   # use CPU or GPU

num_scenes =72
num_episodes_per_scene = 10

batch_size =10

min_distance = 2
max_distance = 18

def pad_collate(batch):
  (xx, yy) = zip(*batch)
  x_lens = [len(x) for x in xx]
  y_lens = [len(y) for y in yy]

  xx_pad = pad_sequence(xx, batch_first=True, padding_value=0)
  yy_pad = pad_sequence(yy, batch_first=True, padding_value=0)

  return xx_pad, yy_pad, x_lens, y_lens


# Data loading parameters
params = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 0, 'pin_memory': True} if use_cuda else {}

data_path   = 'data/datasets/pointnav/gibson/v1/all/training_batch_0.json.gz'
scene_dir   = 'data/scene_datasets/'
mode        = "exact_gradient"
config_path = "configs/tasks/pointnav_gibson.yaml"
transform   = transforms.Compose([transforms.ToTensor()])

expert          = Expert(data_path, scene_dir, mode, config_path, transform)
images, actions = expert.read_observations_and_actions(num_scenes, num_episodes_per_scene,min_distance, max_distance)

train_set = Dataset_RNN(images, actions)  
train_loader = data.DataLoader(train_set, **params, collate_fn = pad_collate)

dataiter = iter(train_loader)
images, labels, x_lengths, y_lengths = dataiter.next()
images,labels = images.to(device), labels.to(device)

print(images.shape)
print(labels.shape)

from utils import device, show_one_batch
show_one_batch(train_loader,10,10)
# Out:
# 2020-04-22 21:43:38,827 Initializing dataset PointNav-v1
# 2020-04-22 21:43:38,844 initializing sim Sim-v0
# I0422 21:43:41.640920 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Pettigrew.navmesh
# 2020-04-22 21:43:41,640 - [INFO] - I0422 21:43:41.640920 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Pettigrew.navmesh
# 2020-04-22 21:43:41,646 Initializing task Nav-v0
# Environment creation successful
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:43:44.916455 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Hometown.navmesh
# 2020-04-22 21:43:44,916 - [INFO] - I0422 21:43:44.916455 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Hometown.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:43:48.182015 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Kerrtown.navmesh
# 2020-04-22 21:43:48,182 - [INFO] - I0422 21:43:48.182015 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Kerrtown.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:43:51.781810 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Adrian.navmesh
# 2020-04-22 21:43:51,781 - [INFO] - I0422 21:43:51.781810 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Adrian.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:43:55.137661 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/
18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Superior.navmesh
# 2020-04-22 21:47:02,741 - [INFO] - I0422 21:47:02.741413 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Superior.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:06.218617 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Nimmons.navmesh
# 2020-04-22 21:47:06,218 - [INFO] - I0422 21:47:06.218617 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Nimmons.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:09.549726 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Nuevo.navmesh
# 2020-04-22 21:47:09,549 - [INFO] - I0422 21:47:09.549726 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Nuevo.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:12.875390 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Soldier.navmesh
# 2020-04-22 21:47:12,875 - [INFO] - I0422 21:47:12.875390 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Soldier.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:16.220698 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Silas.navmesh
# 2020-04-22 21:47:16,220 - [INFO] - I0422 21:47:16.220698 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Silas.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:19.639913 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Goffs.navmesh
# 2020-04-22 21:47:19,639 - [INFO] - I0422 21:47:19.639913 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Goffs.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:22.883145 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Roane.navmesh
# 2020-04-22 21:47:22,883 - [INFO] - I0422 21:47:22.883145 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Roane.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:24.172377 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Beach.navmesh
# 2020-04-22 21:47:24,172 - [INFO] - I0422 21:47:24.172377 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Beach.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# I0422 21:47:25.484926 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Angiola.navmesh
# 2020-04-22 21:47:25,484 - [INFO] - I0422 21:47:25.484926 18339 simulator.py:142] Loaded navmesh data/scene_datasets/gibson/Angiola.navmesh
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# Agent stepping around inside environment.
# Episode finished
# torch.Size([10, 124, 3, 256, 256])
# torch.Size([10, 124])
# 100

# %%
show_one_batch(train_loader,5,5)
# Out:
# 25

# %% [markdown]
# ### Visualizing Trainloader data!
#
# load data from dataset, slit it inot training and validations set and visualize data as a grid

# %%
from data import dataset_utils
from utils import show_dataset, max_seq_length,max_seq_length_list
# from data.transformation import val_transform
# from data.transformation import train_transform, val_transform
import numpy as np
import os
import torch
from sklearn.model_selection import train_test_split
import torchvision.transforms as transforms
import torch.utils.data as data

from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch


import torchvision.models as models
import torch.nn as nn

from models import ResCNNEncoder, DecoderRNN

from torch.nn.utils.rnn import pad_sequence

from utils import device, show_one_batch

def pad_collate(batch):
  (xx, yy, zz) = zip(*batch)
  x_lens = [len(x) for x in xx]
  y_lens = [len(y) for y in yy]
  z_lens = [len(z) for z in zz]

  xx_pad = pad_sequence(xx, batch_first=True, padding_value=0)
  yy_pad = pad_sequence(yy, batch_first=True, padding_value=0)
  zz_pad = pad_sequence(zz, batch_first=True, padding_value=0)

  return xx_pad, yy_pad, zz_pad, x_lens, y_lens, z_lens



# training parameters
k = 101             # number of target category
epochs = 120        # training epochs
batch_size = 5 
learning_rate = 1e-4
log_interval = 10   # interval for displaying training info
img_x, img_y = 224, 224 

#Preparing data for datalaoding
begin_frame, end_frame, skip_frame = 3, 20, 1
selected_frames = np.arange(begin_frame, end_frame, skip_frame).tolist()

# print(selected_frames)

# Detect devices
use_cuda = torch.cuda.is_available()                   # check if GPU exists
device = torch.device("cuda" if use_cuda else "cpu")   # use CPU or GPU

# Data loading parameters
params = {'batch_size': batch_size, 'shuffle': True, 'num_workers': 0, 'pin_memory': True} if use_cuda else {}


transform = transforms.Compose([transforms.Resize([img_x, img_y]),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_path = project.data_dir
fnames = os.listdir(data_path)
all_names = []
for f in fnames:
    all_names.append(f)


all_X_list = all_names

print(len(all_names))
train_list, test_list = train_test_split(all_X_list,test_size=0.20, random_state=42)

print(len(train_list))
train_list,val_list = train_test_split(train_list, test_size=0.25, random_state=1)

train_seq_length, max_tsq_length, min_tsq_length = max_seq_length_list(train_list)
val_seq_length, max_vsq_length, min_vsq_length = max_seq_length_list(val_list)
test_seq_length, max_tssq_length, min_tssq_length = max_seq_length_list(test_list)

train_set = dataset_utils.Dataset_RNN(data_path, train_list, train_seq_length, transform=transform)  
train_loader = data.DataLoader(train_set, **params, collate_fn = pad_collate)
log_interval = 5
counter = 0
N_count = 0
for batch_idx, (X, y, pose, x_lengths, y_lengths, pose_lengths) in enumerate(train_loader):
    
    print(x_lengths)
    print(y_lengths)
    print(pose_lengths)
    
#     N_count += X.size(0)
#     if (batch_idx + 1) % log_interval == 0:
#         print(batch_idx+1)
#         print('[{}/{} ({:.0f}%)]'.format(N_count, len(train_loader.dataset), 100. * (batch_idx + 1) / len(train_loader)))
    
    
    


# dataiter = iter(train_loader)
# images, labels, pose,  x_lengths, y_lengths, pose_lengths = dataiter.next()
# images,labels, pose = images.to(device), labels.to(device), pose.to(device)

# def create_mask(batchsize, max_length, length,device):
#     """Given the length create a mask given a padded tensor"""
#     tensor_mask = torch.zeros(batchsize, max_length, dtype = torch.bool)
#     for idx, row in enumerate(tensor_mask):
#         row[:length[idx]] = 1

#     tensor_mask.unsqueeze_(-1)
#     return tensor_mask.to(device)


# # EncoderCNN architecture
# CNN_fc_hidden1, CNN_fc_hidden2,CNN_fc_hidden3 = 1500,1024,512
# CNN_embed_dim = 300      # latent dim extracted by 2D CNN
# img_x, img_y = 224,224 #Specify crop image sizes here 
# dropout_p_CNN = 0.3          # dropout probability
# pose_feature_dim = 72

# # DecoderRNN architecture
# RNN_hidden_layers = 3
# RNN_hidden_nodes = 128
# RNN_FC_dim = 64
# output_dim =2
# dropout_p_RNN = 0.3          # dropout probability

# cnn_encoder = ResCNNEncoder(fc_hidden1=CNN_fc_hidden1, fc_hidden2=CNN_fc_hidden2, drop_p=dropout_p_CNN, CNN_embed_dim=CNN_embed_dim).to(device)
# rnn_decoder = DecoderRNN(embed_dim=CNN_embed_dim+pose_feature_dim, h_RNN_layers=RNN_hidden_layers, num_hidden=RNN_hidden_nodes, h_FC_dim=RNN_FC_dim, drop_prob=dropout_p_RNN, output_dim=output_dim).to(device)
# # # # print(cnn_encoder)

# encoder_out = cnn_encoder(images)
# embed_mask = create_mask(encoder_out.shape[0],encoder_out.shape[1], x_lengths,device)
# embed_mask = embed_mask.expand_as(encoder_out)
# encoder_out = encoder_out*embed_mask

# print(encoder_out.shape)

# encoder_out = torch.cat((encoder_out, pose),2)
# print(encoder_out.shape)
# h = rnn_decoder.init_hidden(batch_size)
# output,h = rnn_decoder(encoder_out,h, x_lengths)   # output has dim = (batch*seq_length, number of outputs)
# Out:
# 932
# 745
# 5
# [50/558 (9%)]
# 10
# [100/558 (18%)]
# 15
# [150/558 (27%)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c7f212284605> in <module>
#      90 counter = 0
#      91 N_count = 0
# ---> 92 for batch_idx, (X, y, pose, x_lengths, y_lengths, pose_lengths) in enumerate(train_loader):
#      93     N_count += X.size(0)
#      94     if (batch_idx + 1) % log_interval == 0:
#
# ~/anaconda3/envs/py3-gibson/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/py3-gibson/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/py3-gibson/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/py3-gibson/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/hierarchical_imitation/learning_module/data/dataset_utils.py in __getitem__(self, index)
#      67         # Load data
#      68         # X = self.read_images_and_actions(self.data_path, folder, self.frames, self.transform)     # (input) spatial images
# ---> 69         X      = self.read_images_and_actions(self.data_path, folder, frame, self.transform)     # (input) spatial images
#      70         y      = torch.FloatTensor([self.labels]).squeeze_(0)                  # (labels)  FloatTensor
#      71         x_add  = torch.FloatTensor([self.pose]).squeeze_(0)                  # (poses) LongTensor are for int64 instead of FloatTensor
#
# ~/hierarchical_imitation/learning_module/data/dataset_utils.py in read_images_and_actions(self, path, selected_folder, frames, use_transform)
#      34         #Load pose data
#      35         pose_pd = pd.read_csv(pose_filename, delimiter=' ', names = ["pos_x", "pos_y", "pos_z", "yaw", "pitch","roll"])
# ---> 36         pose_pd = feature_engineering_poses(pose_pd)
#      37         begin_frame, end_frame, skip_frame = 3, frames, 1
#      38         selected_frames = np.arange(begin_frame, end_frame, skip_frame).tolist()
#
# ~/hierarchical_imitation/learning_module/utils.py in feature_engineering_poses(data_frame)
#     109
#     110     #Basic features
# --> 111     data_frame = feat_eng(data_frame)
#     112     data_frame = data_frame.fillna(0)
#     113     data_frame = data_frame.values
#
# ~/hierarchical_imitation/learning_module/utils.py in feat_eng(data)
#      95         data[col + '_mean'] = data[col].mean()
#      96         data[col + '_median'] = data[col].median()
# ---> 97         data[col + '_max'] = data[col].max()
#      98         data[col + '_min'] = data[col].min()
#      99         data[col + '_std'] = data[col].std()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2971                 if self.columns.nlevels > 1:
#    2972                     return self._getitem_multilevel(key)
# -> 2973                 return self._get_item_cache(key)
#    2974
#    2975         # Do we have a slicer (on rows)?
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3269         if res is None:
#    3270             values = self._data.get(item)
# -> 3271             res = self._box_item_values(item, values)
#    3272             cache[item] = res
#    3273             res._set_as_cached(item, self)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _box_item_values(self, key, values)
#    3458
#    3459     def _box_item_values(self, key, values):
# -> 3460         items = self.columns[self.columns.get_loc(key)]
#    3461         if values.ndim == 2:
#    3462             return self._constructor(values.T, columns=items, index=self.index)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4277
#    4278         if is_scalar(key):
# -> 4279             key = com.cast_scalar_indexer(key)
#    4280             return getitem(key)
#    4281
#
# ~/.local/lib/python3.6/site-packages/pandas/core/common.py in cast_scalar_indexer(val)
#     161     """
#     162     # assumes lib.is_scalar(val)
# --> 163     if lib.is_float(val) and val == int(val):
#     164         return int(val)
#     165     return val
#
# KeyboardInterrupt:

# %%
print(pose[3,:,:])

print(labels[3,:,:])

# # print(images[0,76,:,:,:].cpu().numpy().transpose(1, 2, 0))

# blank_image = images[0,76,:,:,:].unsqueeze(0)

# import torchvision.models as models
# resnet = models.resnet152(pretrained=True)

# modules = list(resnet.children())[:-1]      # delete the last fc layer.
# resnet = nn.Sequential(*modules).to(device)

# im_out = resnet(blank_image)

# im_out=im_out.view(-1,1)

# print(images.shape)

# plt.imshow(images[1,34,:,:,:].cpu().numpy().transpose(1, 2, 0))

# plt.show()

# print(output[1,34,:])
# # dataiter = iter(train_loader)
# # images, labels, x_lens, y_lens = dataiter.next()
# # images,labels = images.to(device), labels.to(device)

# # print(images.shape)
# # print(labels.shape)
# # print(x_lens)
# # print(y_lens)
# Out:
# tensor([[-3.1954e+00, -2.3497e+00,  2.7826e-01,  ...,  1.6521e-01,
#           1.0528e+00,  6.1300e-05],
#         [-3.1954e+00, -2.3496e+00,  2.0316e-01,  ...,  1.6521e-01,
#           1.0528e+00,  8.4403e-05],
#         [-3.1954e+00, -2.3496e+00,  1.1142e-01,  ...,  1.6521e-01,
#           1.0528e+00,  1.0990e-04],
#         ...,
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  ...,  0.0000e+00,
#           0.0000e+00,  0.0000e+00]], device='cuda:0')
# tensor([[ 0.9897,  0.0029],
#         [ 0.9897,  0.0029],
#         [ 0.9897,  0.0029],
#         [ 0.9897,  0.0029],
#         [ 0.9897,  0.0029],
#         [ 0.9897,  0.0029],
#         [ 0.9898,  0.0111],
#         [ 0.9899,  0.0191],
#         [ 0.9902,  0.0272],
#         [ 0.9906,  0.0348],
#         [ 0.9908,  0.0418],
#         [ 0.9908,  0.0489],
#         [ 0.9914,  0.0566],
#         [ 0.9922,  0.0643],
#         [ 0.9931,  0.0722],
#         [ 0.9941,  0.0798],
#         [ 0.9951,  0.0874],
#         [ 0.9963,  0.0949],
#         [ 0.9977,  0.1023],
#         [ 0.9991,  0.1097],
#         [ 1.0007,  0.1170],
#         [ 1.0024,  0.1242],
#         [ 1.0043,  0.1314],
#         [ 1.0063,  0.1384],
#         [ 1.0084,  0.1454],
#         [ 1.0107,  0.1522],
#         [ 1.0131,  0.1589],
#         [ 1.0158,  0.1655],
#         [ 1.0186,  0.1720],
#         [ 1.0216,  0.1783],
#         [ 1.0237, -0.0110],
#         [ 1.0227, -0.2228],
#         [ 1.0178, -0.4446],
#         [ 1.0092, -0.6814],
#         [ 0.9975, -0.9321],
#         [ 0.9669, -1.2116],
#         [ 0.9360, -1.5076],
#         [ 0.9158, -1.6734],
#         [ 0.9099, -1.6004],
#         [ 0.9121, -1.5115],
#         [ 0.9197, -1.4149],
#         [ 0.9307, -1.3109],
#         [ 0.9443, -1.2031],
#         [ 0.9600, -1.0945],
#         [ 0.9761, -0.9899],
#         [ 0.9873, -0.8880],
#         [ 0.9991, -0.7874],
#         [ 1.0105, -0.6911],
#         [ 1.0216, -0.5993],
#         [ 1.0319, -0.5119],
#         [ 1.0412, -0.4284],
#         [ 1.0493, -0.3504],
#         [ 1.0561, -0.2733],
#         [ 1.0616, -0.1987],
#         [ 1.0655, -0.1258],
#         [ 1.0678, -0.0541],
#         [ 1.0684,  0.0171],
#         [ 1.0674,  0.0885],
#         [ 1.0647,  0.1624],
#         [ 1.0603,  0.2379],
#         [ 1.0545,  0.3138],
#         [ 1.0471,  0.3817],
#         [ 1.0395,  0.3660],
#         [ 1.0325,  0.3494],
#         [ 1.0262,  0.3318],
#         [ 1.0206,  0.3139],
#         [ 1.0154,  0.2948],
#         [ 1.0108,  0.2750],
#         [ 1.0066,  0.2546],
#         [ 1.0030,  0.2341],
#         [ 0.9998,  0.2127],
#         [ 0.9969,  0.1908],
#         [ 0.9945,  0.1690],
#         [ 0.9924,  0.1464],
#         [ 0.9907,  0.1241],
#         [ 0.9892,  0.1010],
#         [ 0.9881,  0.0783],
#         [ 0.9873,  0.0548],
#         [ 0.9867,  0.0319],
#         [ 0.9864,  0.0083],
#         [ 0.9865, -0.0147],
#         [ 0.9868, -0.0383],
#         [ 0.9873, -0.0612],
#         [ 0.9882, -0.0846],
#         [ 0.9893, -0.1073],
#         [ 0.9908, -0.1276],
#         [ 0.9923, -0.1194],
#         [ 0.9938, -0.1112],
#         [ 0.9953, -0.1029],
#         [ 0.9966, -0.0948],
#         [ 0.9991, -0.0787],
#         [ 1.0008, -0.0652],
#         [ 1.0018, -0.0525],
#         [ 1.0004, -0.0407],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000],
#         [ 0.0000,  0.0000]], device='cuda:0')

# %%
plt.matshow(images[0,34,:,:,:].cpu().numpy().transpose(1, 2, 0))
plt.show()

print (images[0,35,:,:,:].cpu().numpy().transpose(1, 2, 0))
# print(images[0,1,:,:,:].cpu().numpy().transpose(1, 2, 0).shape)
# Out:
# <img src="data:image/png;base64,..." width="479.9999895962804">
# <img src="data:image/png;base64,..." width="479.9999895962804">
# <img src="data:image/png;base64,..." width="479.9999895962804">
# <img src="data:image/png;base64,..." width="479.9999895962804">
# [[[0.00392157 0.00392157 0.        ]
#   [0.08627451 0.07843138 0.07450981]
#   [0.13333334 0.11764706 0.12156863]
#   ...
#   [0.4745098  0.43529412 0.39215687]
#   [0.39607844 0.35686275 0.32156864]
#   [0.4745098  0.43529412 0.39607844]]
#
#  [[0.01568628 0.01568628 0.01960784]
#   [0.16862746 0.16078432 0.16862746]
#   [0.50980395 0.49019608 0.50980395]
#   ...
#   [0.47058824 0.43137255 0.38431373]
#   [0.46666667 0.42745098 0.38431373]
#   [0.4745098  0.43529412 0.4       ]]
#
#  [[0.28627452 0.28627452 0.30980393]
#   [0.39607844 0.38431373 0.42745098]
#   [0.6666667  0.6431373  0.6862745 ]
#   ...
#   [0.47058824 0.43137255 0.38431373]
#   [0.46666667 0.42745098 0.3882353 ]
#   [0.46666667 0.42745098 0.39607844]]
#
#  ...
#
#  [[0.54901963 0.49411765 0.52156866]
#   [0.50980395 0.45490196 0.48235294]
#   [0.56078434 0.5058824  0.5411765 ]
#   ...
#   [0.69803923 0.57254905 0.44313726]
#   [0.69803923 0.5686275  0.44313726]
#   [0.7058824  0.57254905 0.4509804 ]]
#
#  [[0.54509807 0.4862745  0.5137255 ]
#   [0.49411765 0.43529412 0.4627451 ]
#   [0.5568628  0.49803922 0.5294118 ]
#   ...
#   [0.69411767 0.5764706  0.43529412]
#   [0.69803923 0.57254905 0.4392157 ]
#   [0.7019608  0.57254905 0.4392157 ]]
#
#  [[0.5411765  0.48235294 0.50980395]
#   [0.53333336 0.4745098  0.5019608 ]
#   [0.54901963 0.49019608 0.5176471 ]
#   ...
#   [0.6862745  0.5764706  0.43137255]
#   [0.6901961  0.57254905 0.43137255]
#   [0.69803923 0.57254905 0.43137255]]]

# %%
from numpy import genfromtxt
import numpy as np
import pandas as pd
pose_filename ='/home/mirshad7/hierarchical_imitation/learning_module/dataset/Allensville20/pose.csv'
pose = genfromtxt(pose_filename, delimiter=' ')

pose_pd = pd.read_csv(pose_filename, delimiter=' ', names = ["pos_x", "pos_y", "pos_z", "yaw", "pitch","roll"])

frames = 254


# begin_frame, end_frame, skip_frame = 3, frames, 1
# selected_frames = np.arange(begin_frame, end_frame, skip_frame).tolist()

# selected_columns = [0,1,3,4]
# pose = pose[selected_frames, :][:, selected_columns]


pose_pd[pose_pd.columns[-3:]]= pose_pd[pose_pd.columns[-3:]]*np.pi/180
pose_pd['roll'] =  pose_pd['roll'].abs()

#Basic features
def feat_eng(data):
    data['totl_xyz'] = (data['pos_x']**2 + data['pos_y']**2 + data['pos_z']**2)**0.5
    data['totl_ang_xyz'] = (data['roll']**2 + data['pitch']**2 + data['yaw']**2)**0.5
    
    def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))
    
    for col in data.columns:
        data[col + '_mean'] = data[col].mean()
        data[col + '_median'] = data[col].median()
        data[col + '_max'] = data[col].max()
        data[col + '_min'] = data[col].min()
        data[col + '_std'] = data[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_change'] = data[col].diff()
#         data[col + '_mean_change_of_abs_change'] = data[col].apply(mean_change_of_abs_change)
    return data

pose_pd = feat_eng(pose_pd)
pose_pd = pose_pd.fillna(0)
pose_pd= pose_pd.values

print(pose_pd)



#For orientation (last 3 columns) adjust angle
# Out:
# [[ 4.25052530e+00  1.10790246e+00  8.36534741e-02 ...  4.85881708e-01
#    1.15698180e+00  0.00000000e+00]
#  [ 4.25052332e+00  1.10791581e+00  5.91062940e-02 ...  4.85881708e-01
#    1.15698180e+00  2.08253765e-05]
#  [ 4.25052128e+00  1.10792952e+00  1.76160052e-02 ...  4.85881708e-01
#    1.15698180e+00  3.85765176e-05]
#  ...
#  [ 3.54559104e+00  6.54885929e+00  1.02254853e-02 ...  4.85881708e-01
#    1.15698180e+00  3.36902881e-03]
#  [ 3.52198471e+00  6.57780503e+00  1.04292146e-02 ...  4.85881708e-01
#    1.15698180e+00  1.48354271e-03]
#  [ 3.50074916e+00  6.60368298e+00  1.02259521e-02 ...  4.85881708e-01
#    1.15698180e+00 -5.06369365e-03]]

# %%
# Out:
# tensor([0, 1, 2])

# %%
# Out:
# 1.0

# %%
from Project import Project
project = Project()
import os
data_path = project.data_dir
fnames = os.listdir(data_path)
all_names = []
for f in fnames:
    all_names.append(f)
print(all_names)

import numpy as np
np.savetxt("env_list.csv", all_names, fmt='%s')

for i in range(len(all_names)):
    folder_dir = os.path.join(daata_path, all_names[i])
# Out:
# ['Hominy65', 'Natural86', 'Wyldwood36', 'Hominy75', 'Highspire67', 'Ancor96', 'Wando79', 'Kobuk31', 'Wando92', 'Newfields14', 'Marland49', 'Kemblesville49', 'Globe79', 'Lynchburg79', 'Pomaria88', 'Byers1', 'Pittsburg80', 'Tolstoy40', 'Castor89', 'Kemblesville32', 'Victorville96', 'Castor49', 'Hillsdale47', 'Shelbiana43', 'Springerville58', 'Lynchburg39', 'Markleeville11', 'Allensville35', 'Nuevo74', 'Byers81', 'Collierville95', 'Forkland99', 'Kobuk76', 'Pittsburg14', 'Pablo75', 'Noxapater19', 'Natural20', 'Maida97', 'Arkansaw84', 'Hominy78', 'Hominy89', 'Rosser70', 'Swormville91', 'Allensville93', 'Maida37', 'Bohemia11', 'Wiconisco30', 'Rosser25', 'Pomaria52', 'Hordville92', 'Donaldson86', 'Nuevo70', 'Waipahu86', 'Hordville82', 'Darden72', 'Hildebran17', 'Airport33', 'Benevolence82', 'Rosser76', 'Mifflinburg95', 'Sugarville18', 'Wilseyville95', 'Goffs89', 'Maida90', 'Benevolence88', 'Pittsburg71', 'Castor62', 'Hortense88', 'Springerville71', 'Forkland36', 'Collierville36', 'Sands41', 'Andover69', 'Byers91', 'Anaheim26', 'Natural5', 'Stilwell89', 'Maida52', 'Swisshome46', 'Wando80', 'Sussex29', 'Maida70', 'Pittsburg31', 'Byers69', 'Goodfield54', 'Pittsburg96', 'Collierville84', 'Wando30', 'Hillsdale90', 'Hordville32', 'Wando26', 'Shelbiana59', 'Lynchburg96', 'Kemblesville57', 'Pittsburg78', 'Wyldwood80', 'Bautista27', 'Rosser83', 'Wando61', 'Oyens99', 'Nuevo86', 'Lynchburg94', 'Wilseyville93', 'Hillsdale70', 'Swisshome53', 'Tyler53', 'Wiconisco32', 'Wando57', 'Pittsburg23', 'Emmaus56', 'Neibert35', 'Lynchburg